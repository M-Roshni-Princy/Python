# %%
print('hello')
# Out:
# hello

# %%
print("NAME=M.Roshni Princy")
print("COLLEGE NAME=NIST")
# Out:
# NAME=M.Roshni Princy
# COLLEGE NAME=NIST

# %%
print(2+3)# maually
#using variables
a=12
b=34
print(a+b)
# Out:
# 5
# 46

# %%
#manually
n=2
square=n*n
print(square)
#using input
n1=int(input("enter a number="))
print(n1**2)
# Out:
# 4
# enter a number=3
# 9

# %%
age=int(input("Enter your age="))
print("Your age is =",age)
# Out:
# Enter your age=19
# Your age is = 19

# %%
n1=int(input("Enter 1st number="))
n2=int(input("Enter 2nd number="))
print("n1 is=",n1)
print("n2 is=",n2)
print("After swapping two number")
temp=n1
n1=n2
n2=temp
print("n1 is=",n1)
print("n2 is=",n2)
# Out:
# Enter 1st number=13
# Enter 2nd number=24
# n1 is= 13
# n2 is= 24
# After swapping two number
# n1 is= 24
# n2 is= 13
